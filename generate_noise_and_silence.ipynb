# %%
import numpy as np
import matplotlib.pyplot as plt
import librosa 
import librosa.display
import soundfile as sf

# %%
x = np.random.uniform(low=0.0, high=0.1, size=(160000,))

# %%
import IPython.display as ipd
ipd.Audio(x, rate=16000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
plt.figure(figsize=(14, 5))
librosa.display.waveplot(x, sr=16000)

# %%
data, sr = readAudio('wav/music+speech_noisy7.wav')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-2e0f97f43470> in <module>
# ----> 1 data, sr = readAudio('wav/music+speech_noisy7.wav')
#
# NameError: name 'readAudio' is not defined

# %%
sf.write("example1.wav", x,  16000)
